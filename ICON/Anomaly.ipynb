# %%
import numpy as np
import pandas as pd
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import LinearSegmentedColormap
import pylab as pl
import matplotlib
import seaborn as sns
from datetime import datetime 
import scipy
from scipy.io import netcdf
from colour import Color
import netCDF4 as nc
from netCDF4 import Dataset as NetCDFFile 
import csv
from numpy import arange, dtype 
import xarray as xr
import matplotlib.gridspec as gridspec
#import cartopy.crs as ccrs
#from cartopy import feature as cf
import os
os.environ["PROJ_LIB"] = "/Users/onurhanaydin/opt/anaconda3/envs/geo_env2/share/basemap/epsg"
from mpl_toolkits.basemap import Basemap, shiftgrid
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
pd.set_option("display.max_columns", 20)
pd.set_option("display.max_rows", 20) 
pd.options.display.float_format = "{:.3f}".format 

ipath="/Users/onurhanaydin/Desktop/"
opath="/Users/onurhanaydin/Desktop/"

# %%
ds1=xr.open_dataset(ipath+"file1.nc")
ds2=xr.open_dataset(ipath+"file2.nc")
ds3=xr.open_dataset(ipath+"file3.nc")

# %%
nc1 = NetCDFFile(ipath+"file1.nc")
nc2 = NetCDFFile(ipath+"file2.nc")
nc3 = NetCDFFile(ipath+"file3.nc")

# %%
lat2 = nc2.variables['lat'][:]
lon2 = nc2.variables['lon'][:]
lat3 = nc3.variables['lat'][:]
lon3 = nc3.variables['lon'][:]
time = nc2.variables['time'][:]
sp2 = nc2.variables['pres_sfc'][:]
sp3 = nc3.variables['pres_sfc'][:]
sp2=sp2/100
sp3=sp3/100

fig=plt.figure(figsize=(15,15))

fig.suptitle("Surface Pressure", fontsize=18, fontweight="bold")

# The First Time Step 

fig.add_subplot(321)
plt.title("First Time Step", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-127,llcrnrlat=0.,urcrnrlon=-54.,urcrnrlat=70.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-130,-50,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon2-180,lat2)
x,y = map(lons,lats)
sfc_p2 = map.contourf(x,y,sp2[0,:,:], (940,950,960,970,980,990,1000,1010,1020,1030,1040), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p2,"right", size="2%", pad="4%")
cb.set_label('Pressure (hPa)')
plt.tight_layout()

fig.add_subplot(322)
plt.title("First Time Step", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-51.,llcrnrlat=05.,urcrnrlon=31.,urcrnrlat=75.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-60,80,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon3-180,lat3)
x,y = map(lons,lats)
sfc_p3 = map.contourf(x,y,sp3[0,:,:], (940,950,960,970,980,990,1000,1010,1020,1030,1040), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p3,"right", size="2%", pad="4%")
cb.set_label('Pressure (hPa)')
plt.tight_layout()

# Middle Time Step

fig.add_subplot(323)
plt.title("10th Time Step", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-127,llcrnrlat=0.,urcrnrlon=-54.,urcrnrlat=70.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-130,-50,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon2-180,lat2)
x,y = map(lons,lats)
sfc_p2 = map.contourf(x,y,sp2[10,:,:], (940,950,960,970,980,990,1000,1010,1020,1030,1040), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p2,"right", size="2%", pad="4%")
cb.set_label('Pressure (hPa)')
plt.tight_layout()

fig.add_subplot(324)
plt.title("10th Time Step", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-51.,llcrnrlat=05.,urcrnrlon=31.,urcrnrlat=75.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-60,80,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon3-180,lat3)
x,y = map(lons,lats)
sfc_p3 = map.contourf(x,y,sp3[10,:,:], (940,950,960,970,980,990,1000,1010,1020,1030,1040), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p3,"right", size="2%", pad="4%")
cb.set_label('Pressure (hPa)')
plt.tight_layout()

# The Last Time Step

fig.add_subplot(325)
plt.title("Last Time Step", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-127,llcrnrlat=0.,urcrnrlon=-54.,urcrnrlat=70.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-130,-50,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon2-180,lat2)
x,y = map(lons,lats)
sfc_p2 = map.contourf(x,y,sp2[20,:,:], (940,950,960,970,980,990,1000,1010,1020,1030,1040), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p2,"right", size="2%", pad="4%")
cb.set_label('Pressure (hPa)')
plt.tight_layout()

fig.add_subplot(326)
plt.title("Last Time Step", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-51.,llcrnrlat=05.,urcrnrlon=31.,urcrnrlat=75.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-60,80,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon3-180,lat3)
x,y = map(lons,lats)
sfc_p3 = map.contourf(x,y,sp3[20,:,:], (940,950,960,970,980,990,1000,1010,1020,1030,1040), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p3,"right", size="2%", pad="4%")
cb.set_label('Pressure (hPa)')
plt.tight_layout()

plt.show();
fig.savefig(opath+'surface_pressure.pdf')
fig.savefig(opath+'surface_pressure.png',facecolor='white')

# %%
lat1 = nc1.variables['lat'][:]
lon1 = nc1.variables['lon'][:]
lat2 = nc2.variables['lat'][:]
lon2 = nc2.variables['lon'][:]
lat3 = nc3.variables['lat'][:]
lon3 = nc3.variables['lon'][:]
time = nc1.variables['time'][:]
sp1 = nc1.variables['pres_sfc'][:]
sp2 = nc2.variables['pres_sfc'][:]
sp3 = nc3.variables['pres_sfc'][:]
sp1=sp1/100
sp2=sp2/100
sp3=sp3/100

fig=plt.figure(figsize=(15,15))

fig.suptitle("Anomaly Plots", fontsize=18, fontweight="bold")

# The First Time Step

fig.add_subplot(321)
plt.title("First Time Step of DOM02-DOM01", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-127,llcrnrlat=0.,urcrnrlon=-54.,urcrnrlat=70.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-130,-50,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon2-180,lat2)
x,y = map(lons,lats)
sfc_p2 = map.contourf(x,y,(sp2[0,:,:]-sp1[0,:,:]), (-6,-5,-4,-3,-2,-1,0,1,2), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p2,"right", size="2%", pad="4%")
plt.tight_layout()

fig.add_subplot(322)
plt.title("First Time Step of DOM03-DOM01", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-51.,llcrnrlat=05.,urcrnrlon=31.,urcrnrlat=75.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-60,80,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon3-180,lat3)
x,y = map(lons,lats)
sfc_p3 = map.contourf(x,y,(sp3[0,:,:]-sp1[0,:,:]), (-6,-5,-4,-3,-2,-1,0,1,2), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p3,"right", size="2%", pad="4%")
plt.tight_layout()

# Middle Time Step

fig.add_subplot(323)
plt.title("10th Time Step of DOM02-DOM01", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-127,llcrnrlat=0.,urcrnrlon=-54.,urcrnrlat=70.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-130,-50,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon2-180,lat2)
x,y = map(lons,lats)
sfc_p2 = map.contourf(x,y,(sp2[10,:,:]-sp1[10,:,:]), (-6,-5,-4,-3,-2,-1,0,1,2), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p2,"right", size="2%", pad="4%")
plt.tight_layout()

fig.add_subplot(324)
plt.title("10th Time Step of DOM03-DOM01", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-51.,llcrnrlat=05.,urcrnrlon=31.,urcrnrlat=75.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-60,80,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon3-180,lat3)
x,y = map(lons,lats)
sfc_p3 = map.contourf(x,y,(sp3[10,:,:]-sp1[10,:,:]), (-6,-5,-4,-3,-2,-1,0,1,2), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p3,"right", size="2%", pad="4%")
plt.tight_layout()

# The Last Time Step

fig.add_subplot(325)
plt.title("Last Time Step of DOM02-DOM01", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-127,llcrnrlat=0.,urcrnrlon=-54.,urcrnrlat=70.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-130,-50,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon2-180,lat2)
x,y = map(lons,lats)
sfc_p2 = map.contourf(x,y,(sp2[20,:,:]-sp1[20,:,:]), (-6,-5,-4,-3,-2,-1,0,1,2), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p2,"right", size="2%", pad="4%")
plt.tight_layout()

fig.add_subplot(326)
plt.title("Last Time Step of DOM03-DOM01", fontsize=14)
map = Basemap(projection='cyl',llcrnrlon=-51.,llcrnrlat=05.,urcrnrlon=31.,urcrnrlat=75.,resolution='l')
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(0,80,10) 
meridians = np.arange(-60,80,10)
map.drawparallels(parallels,labels=[1,0,0,0],fontsize=8)
map.drawmeridians(meridians,labels=[0,0,0,1],fontsize=8)
lons,lats= np.meshgrid(lon3-180,lat3)
x,y = map(lons,lats)
sfc_p3 = map.contourf(x,y,(sp3[20,:,:]-sp1[20,:,:]), (-6,-5,-4,-3,-2,-1,0,1,2), latlon=True, cmap="Spectral")
cb = map.colorbar(sfc_p3,"right", size="2%", pad="4%")
plt.tight_layout()

plt.show();
fig.savefig(opath+'anomaly.pdf')
fig.savefig(opath+'anomaly.png',facecolor='white')
